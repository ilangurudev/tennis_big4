# %% [markdown]
# ## Data Download

# %%
import pandas as pd
import urllib2
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
import requests

# %%
base = "http://www.tennis-data.co.uk/"
years = range(2001,2018)
end = "/usopen.csv"


for year in years:
    url = base+str(year)+end
    response = urllib2.urlopen(url)
    html = response.read()

    with open(str(year)+'.csv', 'wb') as f:
        f.write(html)

# %%
df = pd.read_csv("../data/ausopen/2014.csv")

# %%
df.head()
# Out:
#    ATP   Location       Tournament      Date      Series    Court Surface  \
# 0    6  Melbourne  Australian Open  13/01/14  Grand Slam  Outdoor    Hard
# 1    6  Melbourne  Australian Open  13/01/14  Grand Slam  Outdoor    Hard
# 2    6  Melbourne  Australian Open  13/01/14  Grand Slam  Outdoor    Hard
# 3    6  Melbourne  Australian Open  13/01/14  Grand Slam  Outdoor    Hard
# 4    6  Melbourne  Australian Open  13/01/14  Grand Slam  Outdoor    Hard
#
#        Round  Best of       Winner  ...    LBW   LBL   PSW   PSL   SJW   SJL  \
# 0  1st Round        5     Dodig I.  ...   1.53  2.38  1.51  2.76  1.57  2.38
# 1  1st Round        5  Nieminen J.  ...   1.50  2.50  1.54  2.66  1.50  2.63
# 2  1st Round        5   Youzhny M.  ...   1.22  4.00  1.29  4.06  1.22  4.00
# 3  1st Round        5     Falla A.  ...   1.67  2.10  1.96  1.94  1.73  2.10
# 4  1st Round        5   Querrey S.  ...   1.40  2.75  1.45  2.99  1.40  2.88
#
#    MaxW  MaxL  AvgW  AvgL
# 0  1.60  2.80  1.50  2.55
# ...

# %%
df = pd.read_csv("/home/sibi/Downloads/madrid.csv")

# %%
df.head()
# Out:
#    ATP Location      Tournament      Date   Series   Court Surface      Round  \
# 0   60   Madrid  Madrid Masters  12/10/08  Masters  Indoor    Hard  1st Round
# 1   60   Madrid  Madrid Masters  12/10/08  Masters  Indoor    Hard  1st Round
# 2   60   Madrid  Madrid Masters  13/10/08  Masters  Indoor    Hard  1st Round
# 3   60   Madrid  Madrid Masters  13/10/08  Masters  Indoor    Hard  1st Round
# 4   60   Madrid  Madrid Masters  13/10/08  Masters  Indoor    Hard  1st Round
#
#    Best of       Winner  ...  B365W  B365L   EXW   EXL    LBW    LBL    PSW  \
# 0        3  Stepanek R.  ...   1.30   3.40  1.40  3.00  1.300  3.400    NaN
# 1        3    Gulbis E.  ...   1.53   2.37  1.60  2.40  1.533  2.375    NaN
# 2        3      Fish M.  ...   1.53   2.37  1.65  2.25  1.533  2.375  1.676
# 3        3   Bolelli S.  ...   2.10   1.66  2.05  1.78  2.100  1.667  2.070
# 4        3     Simon G.  ...   1.66   2.10  1.65  2.20  1.833  1.833  1.833
#
#      PSL   UBW   UBL
# ...
