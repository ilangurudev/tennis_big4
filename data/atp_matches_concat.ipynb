# %% [markdown]
# ## Merge all datasets

# %%
import pandas as pd
import urllib2
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
import requests
import glob

pd.options.display.max_columns = 500

# %%
path = "./atp_matches/" # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))

# %%
frame = pd.DataFrame()
df = pd.concat((pd.read_csv(f) for f in all_files))

# %%
df_test = pd.read_csv("./atp_matches/atp_matches_1973.csv")

# %%
df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   1975-347  Bournemouth    Clay         64             A      19750512
# 1   1975-347  Bournemouth    Clay         64             A      19750512
# 2   1975-347  Bournemouth    Clay         64             A      19750512
# 3   1975-347  Bournemouth    Clay         64             A      19750512
# 4   1975-347  Bournemouth    Clay         64             A      19750512
#
#    match_num  winner_id  winner_seed winner_entry        winner_name  \
# 0          1     100282          NaN          NaN    Guillermo Vilas
# 1          2     100199          NaN          NaN  Patrice Dominguez
# 2          3     100062          NaN          NaN  Francois Jauffret
# 3          4     100359          NaN          NaN      Richard Lewis
# 4          5     109787          NaN          NaN        Cm Robinson
#
#   winner_hand  winner_ht winner_ioc  winner_age  winner_rank  \
# ...

# %%
#Write to csv
df.to_csv('../data/atp_matches_all.csv',index=False)

# %% [markdown]
# ## Basic

# %%
df.describe()
# Out:
#            draw_size  tourney_date      match_num      winner_id  \
# count  163965.000000  1.639650e+05  163965.000000  163965.000000
# mean       52.583088  1.992108e+07      29.890812  102116.733370
# std        36.065447  1.340284e+05      39.788424    2767.244364
# min         4.000000  1.968012e+07       1.000000  100002.000000
# 25%        32.000000  1.980110e+07       8.000000  100428.000000
# 50%        32.000000  1.992042e+07      20.000000  101481.000000
# 75%        64.000000  2.003082e+07      34.000000  103413.000000
# max       128.000000  2.017020e+07     319.000000  202382.000000
#
#         winner_seed      winner_ht     winner_age   winner_rank  \
# count  63018.000000  145980.000000  160522.000000  139316.00000
# mean       6.154115     184.196595      25.540895      79.65177
# std        5.315176       6.571915       3.894364     120.43674
# min        1.000000     160.000000      14.004107       1.00000
# ...

# %% [markdown]
# Order checks out till Andre Agassi (6th row) but the count doesn't.
#
# https://en.wikipedia.org/wiki/List_of_ATP_Tour_players_by_career_match_wins

# %%
df_t.winner_name.value_counts().head(13)
# Out:
# Jimmy Connors      1229
# Roger Federer      1097
# Ivan Lendl         1065
# Guillermo Vilas     937
# John Mcenroe        881
# Andre Agassi        861
# Ilie Nastase        826
# Rafael Nadal        822
# Stefan Edberg       796
# Novak Djokovic      768
# Pete Sampras        763
# Boris Becker        711
# David Ferrer        701
# Name: winner_name, dtype: int64

# %%
df.loser_name.value_counts().head()
# Out:
# Fabrice Santoro    444
# Mikhail Youzhny    387
# Feliciano Lopez    386
# John Alexander     382
# Jonas Bjorkman     361
# Name: loser_name, dtype: int64
