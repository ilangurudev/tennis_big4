# %% [markdown]
# ## Merge all datasets

# %%
import pandas as pd
import urllib2
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
import requests
import glob

pd.options.display.max_columns = 500

# %%
path = "./atp_matches/" # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))

# %%
frame = pd.DataFrame()
df = pd.concat((pd.read_csv(f) for f in all_files))

# %%
df.tail()
# Out:
#      tourney_id                 tourney_name surface  draw_size tourney_level  \
# 3885  1993-D074  Davis Cup G1 PR: PHI vs TPE    Clay          4             D
# 3886  1993-D075  Davis Cup G2 SF: SEN vs RSA    Hard          4             D
# 3887  1993-D075  Davis Cup G2 SF: SEN vs RSA    Hard          4             D
# 3888  1993-D075  Davis Cup G2 SF: SEN vs RSA    Hard          4             D
# 3889  1993-D075  Davis Cup G2 SF: SEN vs RSA    Hard          4             D
#
#       tourney_date  match_num  winner_id  winner_seed winner_entry  \
# 3885      19930205          4     109440          NaN          NaN
# 3886      19930924          1     102154          NaN          NaN
# 3887      19930924          2     101965          NaN          NaN
# 3888      19930924          3     101965          NaN          NaN
# 3889      19930924          4     102154          NaN          NaN
#
#           winner_name winner_hand  winner_ht winner_ioc  winner_age  \
# ...

# %%
#Write to csv
df.to_csv('../data/atp_matches_all_new_2.csv',index=False)

# %%
df_test = pd.read_csv("./atp_matches/atp_matches_2017.csv")

# %%
df_test
# Out:
#                           tourney_id                 tourney_name surface  \
# 0                          2017-M020                     Brisbane    Hard
# 1                          2017-M020                     Brisbane    Hard
# 2                          2017-M020                     Brisbane    Hard
# 3                          2017-M020                     Brisbane    Hard
# 4                          2017-M020                     Brisbane    Hard
# 5                          2017-M020                     Brisbane    Hard
# 6                          2017-M020                     Brisbane    Hard
# 7                          2017-M020                     Brisbane    Hard
# 8                          2017-M020                     Brisbane    Hard
# 9                          2017-M020                     Brisbane    Hard
# 10                         2017-M020                     Brisbane    Hard
# 11                         2017-M020                     Brisbane    Hard
# ...

# %% [markdown]
# ## Basic

# %%
df.describe()
# Out:
#            draw_size  tourney_date      match_num      winner_id  \
# count  163965.000000  1.639650e+05  163965.000000  163965.000000
# mean       52.583088  1.992108e+07      29.890812  102116.733370
# std        36.065447  1.340284e+05      39.788424    2767.244364
# min         4.000000  1.968012e+07       1.000000  100002.000000
# 25%        32.000000  1.980110e+07       8.000000  100428.000000
# 50%        32.000000  1.992042e+07      20.000000  101481.000000
# 75%        64.000000  2.003082e+07      34.000000  103413.000000
# max       128.000000  2.017020e+07     319.000000  202382.000000
#
#         winner_seed      winner_ht     winner_age   winner_rank  \
# count  63018.000000  145980.000000  160522.000000  139316.00000
# mean       6.154115     184.196595      25.540895      79.65177
# std        5.315176       6.571915       3.894364     120.43674
# min        1.000000     160.000000      14.004107       1.00000
# ...

# %% [markdown]
# Order checks out till Andre Agassi (6th row) but the count doesn't.
#
# https://en.wikipedia.org/wiki/List_of_ATP_Tour_players_by_career_match_wins

# %%
df_rafa = df_t[(df_t.winner_name == "Rafael Nadal") & (df_t.tourney_level=="G") & (df_t['round']=="F")]

# %%
df_t[(df_t.winner_name == "Rafael Nadal") & (df_t.tourney_level=="G") & (df_t.round=="F")]
# Out:
# Empty DataFrame
# Columns: [tourney_id, tourney_name, surface, draw_size, tourney_level, tourney_date, match_num, winner_id, winner_seed, winner_entry, winner_name, winner_hand, winner_ht, winner_ioc, winner_age, winner_rank, winner_rank_points, loser_id, loser_seed, loser_entry, loser_name, loser_hand, loser_ht, loser_ioc, loser_age, loser_rank, loser_rank_points, score, best_of, round, minutes, w_ace, w_df, w_svpt, w_1stIn, w_1stWon, w_2ndWon, w_SvGms, w_bpSaved, w_bpFaced, l_ace, l_df, l_svpt, l_1stIn, l_1stWon, l_2ndWon, l_SvGms, l_bpSaved, l_bpFaced]
# Index: []

# %%
df_t.winner_name.value_counts().head(13)
# Out:
# Jimmy Connors      1229
# Roger Federer      1097
# Ivan Lendl         1065
# Guillermo Vilas     937
# John Mcenroe        881
# Andre Agassi        861
# Ilie Nastase        826
# Rafael Nadal        822
# Stefan Edberg       796
# Novak Djokovic      768
# Pete Sampras        763
# Boris Becker        711
# David Ferrer        701
# Name: winner_name, dtype: int64

# %%
df.loser_name.value_counts().head()
# Out:
# Fabrice Santoro    444
# Mikhail Youzhny    387
# Feliciano Lopez    386
# John Alexander     382
# Jonas Bjorkman     361
# Name: loser_name, dtype: int64
